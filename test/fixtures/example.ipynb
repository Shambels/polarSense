# %%
import polars as pl

# %%
df = pl.DataFrame(
    {
        "id": [1, 2, 3, 4],
        "category": ["a", "b", "a", "a"],
        "price": [43, 52, 67, 34],
        "quantity": [10, 11, 12, 13],
        "datetime": [
            "2023-01-01 12:00:00",
            "2023-01-02 12:00:00",
            "2023-01-03 12:00:00",
            "2023-01-04 12:00:00",
        ]
    }
)
df
# Out:
# shape: (4, 5)
# ┌─────┬──────────┬───────┬──────────┬─────────────────────┐
# │ id  ┆ category ┆ price ┆ quantity ┆ datetime            │
# │ --- ┆ ---      ┆ ---   ┆ ---      ┆ ---                 │
# │ i64 ┆ str      ┆ i64   ┆ i64      ┆ str                 │
# ╞═════╪══════════╪═══════╪══════════╪═════════════════════╡
# │ 1   ┆ a        ┆ 43    ┆ 10       ┆ 2023-01-01 12:00:00 │
# │ 2   ┆ b        ┆ 52    ┆ 11       ┆ 2023-01-02 12:00:00 │
# │ 3   ┆ a        ┆ 67    ┆ 12       ┆ 2023-01-03 12:00:00 │
# │ 4   ┆ a        ┆ 34    ┆ 13       ┆ 2023-01-04 12:00:00 │
# └─────┴──────────┴───────┴──────────┴─────────────────────┘
